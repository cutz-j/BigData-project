# %%
### 오픈 API 데이터 받아오기 ###
import pandas as pd
from bs4 import BeautifulSoup
import requests

code = {'종로구': '11110', '중구': '11140', '용산구': '11170', '성동구': '11200', 
        '광진구': '11215', '동대문구': '11230', '중랑구': '11260', '성북구': '11290', 
        '강북구': '11305', '도봉구': '11320', '노원구': '11350', '은평구': '11380', 
        '서대문구': '11410', '마포구': '11440', '양천구': '11470', '강서구': '11500',
        '구로구': '11530', '금천구': '11545', '영등포구': '11560', '동작구': '11590',
        '관악구': '11620', '서초구': '11650', '강남구': '11680', '송파구': '11710', '강동구': '11740'}


## URL request --> 받아오기 ## --> 하루 1000트래픽 한정(1 계정당)

url = 'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTrade?'
# 서비스키 중요 --> 공공데이터포털에서 오픈API로 받은 인증키를 여기에 입력
serviceKey = 'serviceKey=' + "9rL%2Fv5RbvEC4bLji%2B3hTKF1wuBPkoVk6nnKg54x54CON8OOz5cLFmRFdIWf38wJmwxilBt4XYpuqm0jzpCoM8w%3D%3D" + "&"


LAWD_CD = 'LAWD_CD=' + code['종로구'] + '&' # 법정 코드 번호 --> 가운데 숫자만 변화주면됨. (위 codedict)
DEAL_YMD = 'DEAL_YMD=' + "201801" # 기간 --> 수집시기는 우리의 몫
url_all = url + serviceKey + LAWD_CD + DEAL_YMD
res = requests.get(url_all)
text = res.text
soup = BeautifulSoup(text,'lxml-xml')
price = soup.select_one("item")
print()
print(price)


for item in soup.select('item'):
    price = item.거래금액.text
    apt = item.아파트.text
    add = item.법정동.text
    howbig = item.전용면적.text
    code = item.지번.text
    floor = item.층.text

    print(apt,'|',add+code,"|",price,"|",howbig,'|',floor+"층")
    print('--------')
# Out:
# <item><거래금액>    17,900</거래금액><건축년도>1999</건축년도><년>2018</년><법정동> 누상동</법정동><아파트>청호그린빌</아파트><월>1</월><일>11~20</일><전용면적>29.76</전용면적><지번>40</지번><지역코드>11110</지역코드><층>4</층></item>
# 청호그린빌 |  누상동40 |     17,900 | 29.76 | 4층
# --------
# 청호그린빌 |  누상동40 |     17,900 | 29.76 | 3층
# --------
# 광화문풍림스페이스본(9-0) |  사직동9 |    110,000 | 146.92 | 9층
# --------
# 광화문풍림스페이스본(9-0) |  사직동9 |     89,000 | 94.51 | 6층
# --------
# 광화문풍림스페이스본(9-0) |  사직동9 |     85,000 | 95.88 | 2층
# --------
# 광화문풍림스페이스본(9-0) |  사직동9 |    100,000 | 108.55 | 1층
# --------
# 광화문풍림스페이스본(9-0) |  사직동9 |     85,000 | 94.51 | 3층
# --------
# 광화문풍림스페이스본(9-0) |  사직동9 |     91,000 | 94.51 | 13층
# --------
# 광화문풍림스페이스본(9-0) |  사직동9 |    132,000 | 147.31 | 6층
# --------
# 광화문풍림스페이스본(9-0) |  사직동9 |     85,000 | 94.51 | 5층
# --------
# 세종 |  당주동100 |     66,000 | 104.73 | 3층
# --------
# 경희궁의아침2단지 |  내수동71 |    130,000 | 140.78 | 15층
# --------
# 파크팰리스 |  내수동95 |     96,000 | 103.77 | 5층
# --------
# 경희궁의아침3단지 |  내수동72 |    118,000 | 123.13 | 10층
# --------
# 세종로대우 |  내수동167 |     54,500 | 66.96 | 13층
# --------
# 세종로대우 |  내수동167 |     64,000 | 76.66 | 11층
# --------
# 현대뜨레비앙 |  익선동55 |     29,000 | 46.64 | 5층
# --------
# 현대뜨레비앙 |  익선동55 |     23,500 | 36.08 | 6층
# --------
# 효성쥬얼리시티 |  인의동48-2 |     51,000 | 84.7 | 11층
# --------
# 포레스트힐시티 |  효제동65-2 |     19,000 | 15.879 | 10층
# --------
# 동성아파트(2동) |  동숭동4-157 |     22,000 | 59.34 | 3층
# --------
# 아남1 |  명륜2가4 |     73,000 | 84.9 | 10층
# --------
# 창신쌍용1 |  창신동702 |     39,500 | 54.7 | 8층
# --------
# 창신쌍용1 |  창신동702 |     46,000 | 79.87 | 3층
# --------
# 창신쌍용1 |  창신동702 |     38,000 | 54.7 | 3층
# --------
# 창신쌍용2 |  창신동703 |     52,200 | 106.62 | 12층
# --------
# 동대문맨션 |  창신동578-5 |     39,000 | 89.55 | 3층
# --------
# 두산 |  창신동232 |     35,000 | 59.95 | 6층
# --------
# 창신쌍용2 |  창신동703 |     33,800 | 64.66 | 2층
# --------
# 창신쌍용2 |  창신동703 |     32,000 | 54.7 | 1층
# --------
# 두산 |  창신동232 |     51,000 | 59.95 | 14층
# --------
# 창신쌍용2 |  창신동703 |     36,700 | 64.66 | 3층
# --------
# 창신쌍용2 |  창신동703 |     38,000 | 64.66 | 13층
# --------
# 창신쌍용2 |  창신동703 |     38,600 | 64.66 | 12층
# --------
# 창신쌍용1 |  창신동702 |     39,900 | 54.7 | 5층
# --------
# 창신쌍용2 |  창신동703 |     42,400 | 79.87 | 15층
# --------
# 창신쌍용1 |  창신동702 |     44,800 | 79.87 | 3층
# --------
# 창신쌍용1 |  창신동702 |     46,000 | 79.87 | 14층
# --------
# 브라운스톤창신 |  창신동23-76 |     52,900 | 84.81 | 15층
# --------
# 종로센트레빌 |  숭인동2-1 |     68,000 | 114.67 | 10층
# --------
# 삼전솔하임2차 |  숭인동296-19 |     13,500 | 15 | 7층
# --------
# 종로중흥S클래스 |  숭인동202-3 |     13,650 | 19.466 | 10층
# --------
# 종로청계힐스테이트 |  숭인동766 |     54,000 | 59.9426 | 7층
# --------
# 종로센트레빌 |  숭인동2-1 |     52,500 | 59.92 | 8층
# --------
# 삼전솔하임2차 |  숭인동296-19 |     13,500 | 15 | 6층
# --------
# 버넷하임1 |  숭인동1421 |     14,200 | 17.96 | 13층
# --------
# 삼전솔하임4차 |  숭인동318-2 |     14,000 | 15.09 | 13층
# --------
# 종로센트레빌 |  숭인동2-1 |     50,800 | 59.92 | 1층
# --------
# 삼전솔하임4차 |  숭인동318-2 |     14,000 | 15.09 | 13층
# --------
# 종로청계힐스테이트 |  숭인동766 |     72,000 | 114.7153 | 4층
# --------
# 할리우드파크아파트 |  숭인동56-135 |     34,000 | 68.77 | 6층
# --------
# 종로청계힐스테이트 |  숭인동766 |     49,800 | 59.9426 | 1층
# --------
# 종로청계힐스테이트 |  숭인동766 |     65,000 | 84.9478 | 6층
# --------
# 롯데캐슬천지인 |  숭인동76 |     75,000 | 111.73 | 27층
# --------
# 경희궁자이3BL |  교남동233 |    125,000 | 84.836 | 11층
# --------
# 경희궁자이3BL |  교남동233 |    124,000 | 84.836 | 13층
# --------
# 르트랑시망 |  평창동102 |     72,000 | 140.49 | 1층
# --------
# 벽산블루밍평창힐스 |  평창동45 |     90,000 | 150.94 | 2층
# --------
# 일성빌라트 |  평창동145-5 |     45,000 | 84.99 | 5층
# --------
# 삼성 |  평창동596 |     38,800 | 59.95 | 14층
# --------
# 롯데낙천대 |  평창동72 |     74,500 | 110.53 | 11층
# --------
# 대아파크빌 |  신영동254 |     33,000 | 59.22 | 5층
# --------
# 인왕산아이파크 |  무악동60 |     79,800 | 84.858 | 7층
# --------
# 인왕산2차아이파크 |  무악동88 |     74,800 | 84.4924 | 16층
# --------
# 인왕산아이파크 |  무악동60 |     73,000 | 84.858 | 7층
# --------
# 인왕산2차아이파크 |  무악동88 |     74,500 | 84.4924 | 10층
# --------
# 현대 |  무악동82 |     81,900 | 114.9 | 17층
# --------
# 인왕산아이파크 |  무악동60 |     95,000 | 114.931 | 10층
# --------
# 현대 |  무악동82 |     79,990 | 114.9 | 18층
# --------
# 인왕산2차아이파크 |  무악동88 |     73,900 | 84.4541 | 11층
# --------
# 인왕산2차아이파크 |  무악동88 |     91,500 | 112.8144 | 15층
# --------
# 인왕산아이파크 |  무악동60 |     92,000 | 114.931 | 11층
# --------
# 현대 |  무악동82 |     65,690 | 84.92 | 10층
# --------
# 인왕산2차아이파크 |  무악동88 |     73,500 | 84.0284 | 14층
# --------
# 인왕산아이파크 |  무악동60 |     87,700 | 114.931 | 5층
# --------
# 현대 |  무악동82 |     74,990 | 114.9 | 9층
# --------
# 인왕산2차아이파크 |  무악동88 |     73,000 | 84.0284 | 16층
# --------
# 인왕산아이파크 |  무악동60 |     90,000 | 114.931 | 9층
# --------
# 현대 |  무악동82 |     66,990 | 84.92 | 18층
# --------
# 인왕산아이파크 |  무악동60 |     79,000 | 84.858 | 13층
# --------
# 인왕산2차아이파크 |  무악동88 |     75,000 | 84.748 | 14층
# --------
# 현대 |  무악동82 |     65,900 | 84.92 | 14층
# --------
# 현대 |  무악동82 |     79,790 | 114.9 | 17층
# --------
# 인왕산아이파크 |  무악동60 |     92,700 | 114.931 | 10층
# --------
# 현대 |  무악동82 |     56,990 | 60 | 4층
# --------
# 현대 |  무악동82 |     49,990 | 60 | 13층
# --------
# 현대 |  무악동82 |     49,990 | 60 | 2층
# --------
# 인왕산아이파크 |  무악동60 |    130,000 | 157.289 | 11층
# --------
