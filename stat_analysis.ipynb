# %%
from datacl import Clean
import statsmodels.formula.api as smf
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd

clean=Clean()
df=clean.load_excel("D:/Github/BigData-project/all0830.xlsx")

y=df.iloc[:, :2]
x=df.iloc[:, 1:]

print(df.corr(method='pearson'))

print("\n",res.params)
# Out:
#               price      temp      rain      wind       gas    diesel  \
# price      1.000000 -0.304181  0.467031 -0.103605  0.483211  0.489603
# temp      -0.304181  1.000000  0.472410 -0.372591 -0.907258 -0.908592
# rain       0.467031  0.472410  1.000000  0.434014 -0.385775 -0.400712
# wind      -0.103605 -0.372591  0.434014  1.000000  0.244117  0.237589
# gas        0.483211 -0.907258 -0.385775  0.244117  1.000000  0.999424
# diesel     0.489603 -0.908592 -0.400712  0.237589  0.999424  1.000000
# wondollar -0.745930 -0.050232 -0.469687  0.173526 -0.196039 -0.192932
# stock      0.584306  0.386035  0.774035 -0.464396 -0.143418 -0.136301
#
#            wondollar     stock
# price      -0.745930  0.584306
# temp       -0.050232  0.386035
# rain       -0.469687  0.774035
# wind        0.173526 -0.464396
# gas        -0.196039 -0.143418
# diesel     -0.192932 -0.136301
# wondollar   1.000000 -0.699764
# stock      -0.699764  1.000000
#
#  Intercept   -5479.983999
# ...

# %%
model=smf.ols("price ~ temp", data=df)
res=model.fit()

print(res.summary())
fig = sm.graphics.plot_regress_exog(res, "temp")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.093
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     8.973
# Date:                Thu, 30 Aug 2018   Prob (F-statistic):            0.00356
# Time:                        17:00:45   Log-Likelihood:                -742.81
# No. Observations:                  90   AIC:                             1490.
# Df Residuals:                      88   BIC:                             1495.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3211.2305    169.450     18.951      0.000    2874.485    3547.976
# ...

# %%
model=smf.ols("price ~ rain", data=df)
res=model.fit()

print(res.summary())
fig = sm.graphics.plot_regress_exog(res, "rain")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:72: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   "samples were given." % int(n), ValueWarning)
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                 -0.173
# Method:                 Least Squares   F-statistic:                    0.5579
# Date:                Thu, 30 Aug 2018   Prob (F-statistic):              0.533
# Time:                        17:00:45   Log-Likelihood:                -27.579
# No. Observations:                   4   AIC:                             59.16
# Df Residuals:                       2   BIC:                             57.93
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
model=smf.ols("price ~ wind", data=df)
res=model.fit()

print(res.summary())
fig = sm.graphics.plot_regress_exog(res, "wind")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9548
# Date:                Thu, 30 Aug 2018   Prob (F-statistic):              0.331
# Time:                        17:00:45   Log-Likelihood:                -746.69
# No. Observations:                  90   AIC:                             1497.
# Df Residuals:                      88   BIC:                             1502.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3082.2525    307.346     10.029      0.000    2471.467    3693.038
# ...

# %%
model=smf.ols("price ~ gas", data=df)
res=model.fit()

print(res.summary())
fig = sm.graphics.plot_regress_exog(res, "gas")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.233
# Model:                            OLS   Adj. R-squared:                  0.225
# Method:                 Least Squares   F-statistic:                     26.81
# Date:                Thu, 30 Aug 2018   Prob (F-statistic):           1.41e-06
# Time:                        17:00:45   Log-Likelihood:                -735.21
# No. Observations:                  90   AIC:                             1474.
# Df Residuals:                      88   BIC:                             1479.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -2.1e+04   4596.639     -4.567      0.000   -3.01e+04   -1.19e+04
# ...

# %%
model=smf.ols("price ~ diesel", data=df)
res=model.fit()

print(res.summary())
fig = sm.graphics.plot_regress_exog(res, "diesel")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.240
# Model:                            OLS   Adj. R-squared:                  0.231
# Method:                 Least Squares   F-statistic:                     27.75
# Date:                Thu, 30 Aug 2018   Prob (F-statistic):           9.72e-07
# Time:                        17:00:46   Log-Likelihood:                -734.84
# No. Observations:                  90   AIC:                             1474.
# Df Residuals:                      88   BIC:                             1479.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.787e+04   3925.462     -4.553      0.000   -2.57e+04   -1.01e+04
# ...

# %%
model=smf.ols("price ~ wondollar", data=df)
res=model.fit()

print(res.summary())
fig = sm.graphics.plot_regress_exog(res, "wondollar")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.551
# Method:                 Least Squares   F-statistic:                     105.4
# Date:                Thu, 30 Aug 2018   Prob (F-statistic):           1.72e-16
# Time:                        17:00:46   Log-Likelihood:                -678.63
# No. Observations:                  86   AIC:                             1361.
# Df Residuals:                      84   BIC:                             1366.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.744e+04   3377.255     11.086      0.000    3.07e+04    4.42e+04
# ...

# %%
model=smf.ols("price ~ stock", data=df)
res=model.fit()

print(res.summary())
fig = sm.graphics.plot_regress_exog(res, "stock")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.341
# Model:                            OLS   Adj. R-squared:                  0.334
# Method:                 Least Squares   F-statistic:                     43.55
# Date:                Thu, 30 Aug 2018   Prob (F-statistic):           3.50e-09
# Time:                        17:00:46   Log-Likelihood:                -695.63
# No. Observations:                  86   AIC:                             1395.
# Df Residuals:                      84   BIC:                             1400.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -5479.9840   1254.703     -4.368      0.000   -7975.098   -2984.870
# ...
